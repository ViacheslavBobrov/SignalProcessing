# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
# Generate random data

n_signal = 10000
order = 5001
raw_signal = np.random.uniform(-1, 1, n_signal)

plt.figure(figsize=(15, 7))
plt.plot(raw_signal)

# %%
filtering_kernel = signal.firwin(order, .01)

# WILL PRODUCE ERROR, BECAUSE IT REQUIRES RAW SIGNAL TO BE >3x SIZE OF KERNEL (5001x3=15003)
filtered_signal = signal.filtfilt(filtering_kernel, 1, raw_signal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-2a2a731149b3> in <module>
#       2
#       3 # WILL PRODUCE ERROR, BECAUSE IT REQUIRES RAW SIGNAL TO BE >3x SIZE OF KERNEL (5001x3=15003)
# ----> 4 filtered_signal = signal.filtfilt(filtering_kernel, 1, raw_signal)
#
# c:\users\viacheslav_bobrov\appdata\local\programs\python\python36-32\lib\site-packages\scipy\signal\signaltools.py in filtfilt(b, a, x, axis, padtype, padlen, method, irlen)
#    3144     # method == "pad"
#    3145     edge, ext = _validate_pad(padtype, padlen, x, axis,
# -> 3146                               ntaps=max(len(a), len(b)))
#    3147
#    3148     # Get the steady state of the filter's step response.
#
# c:\users\viacheslav_bobrov\appdata\local\programs\python\python36-32\lib\site-packages\scipy\signal\signaltools.py in _validate_pad(padtype, padlen, x, axis, ntaps)
#    3194     if x.shape[axis] <= edge:
#    3195         raise ValueError("The length of the input vector x must be greater than "
# -> 3196                          "padlen, which is %d." % edge)
#    3197
#    3198     if padtype is not None and edge > 0:
#
# ValueError: The length of the input vector x must be greater than padlen, which is 15003.

# %%
# Dealing with error using reflection
reflection = raw_signal[::-1]
raw_signal_reflected = np.concatenate((reflection, raw_signal, reflection), axis=0)

plt.figure(figsize=(15, 5))
plt.plot(range(0, n_signal), reflection, 'g', label='left reflection')
plt.plot(range(n_signal, n_signal * 2), raw_signal, 'k', label='raw signal')
plt.plot(range(n_signal * 2, n_signal * 3), reflection, 'g', label='right reflection')
plt.legend()

# %%
# NO ERROR IS PRODUCED
filtered_signal = signal.filtfilt(filtering_kernel, 1, raw_signal_reflected)

# cut off left and right reflection data
filtered_signal = filtered_signal[n_signal:n_signal * 2]

plt.figure(figsize=(15, 7))
plt.plot(raw_signal, label='Raw signal')
plt.plot(filtered_signal, label='Filtered signal')
plt.legend()
